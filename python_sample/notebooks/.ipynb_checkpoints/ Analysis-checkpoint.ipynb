# %%
import sys
sys.path.insert(0,"/scratch/palle.a/AirKeyboard/python_sample")
from utils.analysis import *
# %load_ext autoreload 
# %autoreload 2

# %%
logs_path = "scratch/palle.a/AirKeyboard/"

# %%
hanco_3unet_lp = "/scratch/palle.a/AirKeyboard/logs/hanco_3unet.csv"

hanco_cnn_lp = "/scratch/palle.a/AirKeyboard/logs/hanco_cnn.csv"


models = [("Depth-3 U-net" , hanco_3unet_lp),
         ("Simple CNN", hanco_cnn_lp)]


for m_name, lp in models:
    
    
    plot_loss_curve(lp, title = m_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-56cddd3a3221> in <module>
#      11
#      12
# ---> 13     plot_loss_curve(lp, title = m_name)
#
# /scratch/palle.a/AirKeyboard/python_sample/utils/analysis.py in plot_loss_curve(loss_path, title)
#      24     plt.plot(epochs, train_losses, label = "Train")
#      25     plt.plot(epochs, val_losses, label = "Validation")
# ---> 26     plt.y_label("Loss")
#      27     plt.x_label("Epochs")
#      28     plt.title(title)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'y_label'
